# %%
import gspread
import re
import pandas as pd

# %%
gc = gspread.service_account(filename='/Users/sangilkim/Documents/csv-read-7fb03efe621f.json')

# %%
# sh = gc.open('BOM').worksheet('FPA-SMB')
sh1 = gc.open('BOM').get_worksheet(0)

# %%
# df1 = pd.DataFrame(sh1.get_all_records())
df1 = pd.DataFrame(sh1.get_all_values())

# %%
df1
# Out:
#      0                                                  1   \
# 0                                   Bill Of Material (BOM)
# 1
# 2
# 3   No.                                          Reference
# 4     1  C1,C2,C3,C4,C5,C6,C7,C8,C9,C10,C11,C12,C14,C15...
# 5     2  C13,C24,C31,C34,C40,C50,C86,C91,C93,C117,C171,...
# 6     3  C52,C66,C67,C68,C69,C94,C114,C172,C175,C177,C1...
# 7     4  C58,C59,C60,C61,C62,C63,C64,C65,C381,C382,C383...
# 8     5                                C118,C119,C120,C121
# 9     6                                              J1,J2
# 10    7                                                 J3
# 11    8                                                 U1
# 12
#
#                     2                  3                  4        5   \
# 0                            Project Name                MSC
# 1                             Module Spec                 FM
# 2
# 3             Part No.  ECSS/MIL Part No.              Value  Package
# ...
